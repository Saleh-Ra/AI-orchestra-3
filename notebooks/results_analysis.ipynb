# %% [markdown]
# # Phase 9 — Run cost & repeatability analysis
#
# Loads `output/logs/run_*.json`, builds the token/cost table, and saves charts to `docs/charts/`.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve()
if ROOT.name == "notebooks":
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT))

from src.analysis.logs import load_run_logs, summarize_runs
from src.analysis.report import write_results_report

runs = load_run_logs()
rows = summarize_runs(runs)
report = write_results_report(rows)
print(f"Analyzed {len(rows)} runs -> {report}")

# %%
for r in sorted(rows, key=lambda x: x["timestamp"], reverse=True):
    print(r["timestamp"][:16], r["success"], f"${r['cost_usd']:.4f}", r["topic"][:50])

# %%
from IPython.display import Image, display

chart = ROOT / "docs" / "charts" / "run_cost_comparison.png"
if chart.is_file():
    display(Image(filename=str(chart)))
else:
    print("Chart not generated yet.")
